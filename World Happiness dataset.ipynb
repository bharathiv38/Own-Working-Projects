# %%
#import libraries
import pandas as pd
import numpy as np

# %%
hr = pd.read_csv(r'C:\Users\Laptop\Downloads\New folder\2015.csv')

# %%
hr.head(1).T
# Out:
#                                             0
# Country                           Switzerland
# Region                         Western Europe
# Happiness Rank                              1
# Happiness Score                         7.587
# Standard Error                        0.03411
# Economy (GDP per Capita)              1.39651
# Family                                1.34951
# Health (Life Expectancy)              0.94143
# Freedom                               0.66557
# Trust (Government Corruption)         0.41978
# Generosity                            0.29678
# Dystopia Residual                     2.51738

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
hr.describe().T
# Out:
#                                count       mean        std      min  \
# Happiness Rank                 158.0  79.493671  45.754363  1.00000
# Happiness Score                158.0   5.375734   1.145010  2.83900
# Standard Error                 158.0   0.047885   0.017146  0.01848
# Economy (GDP per Capita)       158.0   0.846137   0.403121  0.00000
# Family                         158.0   0.991046   0.272369  0.00000
# Health (Life Expectancy)       158.0   0.630259   0.247078  0.00000
# Freedom                        158.0   0.428615   0.150693  0.00000
# Trust (Government Corruption)  158.0   0.143422   0.120034  0.00000
# Generosity                     158.0   0.237296   0.126685  0.00000
# Dystopia Residual              158.0   2.098977   0.553550  0.32858
#
#                                      25%        50%         75%        max
# Happiness Rank                 40.250000  79.500000  118.750000  158.00000
# Happiness Score                 4.526000   5.232500    6.243750    7.58700
# Standard Error                  0.037268   0.043940    0.052300    0.13693
# Economy (GDP per Capita)        0.545808   0.910245    1.158448    1.69042
# Family                          0.856823   1.029510    1.214405    1.40223
# Health (Life Expectancy)        0.439185   0.696705    0.811013    1.02525
# Freedom                         0.328330   0.435515    0.549092    0.66973
# Trust (Government Corruption)   0.061675   0.107220    0.180255    0.55191
# Generosity                      0.150553   0.216130    0.309883    0.79588
# Dystopia Residual               1.759410   2.095415    2.462415    3.60214

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.stripplot(hr['Dystopia Residual'])
# Out:
# C:\Users\Laptop\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Dystopia Residual'>

# %%
sns.distplot(hr['Dystopia Residual'],kde=False)
# Out:
# C:\Users\Laptop\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Dystopia Residual'>

# %%
sns.distplot(hr['Dystopia Residual'],kde=True)
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %%
sns.boxplot(hr['Dystopia Residual'])
# Out:
# C:\Users\Laptop\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Dystopia Residual'>

# %%
import numpy as np
def box_plot_calculation(data):
    data = data.values
    q25,q75 = np.percentile(data,25),np.percentile(data,75)
    print("Quartile 25: {}| Quartile 75: {}".format(q25,75))
    IQR = q75-q25
    print('IQR: {}'.format(IQR))
    
    cut_off = IQR =1.5
    MIN, MAX = q25 - cut_off,q75 +cut_off
    print('Cut Off: {}'.format(cut_off))
    print('Minimum: {}'.format(MIN))
    print('Maximum: {}'.format(MAX))
    
    outliers = [x for x in data if x < MIN or x > MAX]
    outliers.sort()
    print('Feature Outliers: {}'.format(len(outliers)))
    print('outliers: {}'.format(outliers))

# %%
box_plot_calculation(hr['Dystopia Residual'])
# Out:
# Quartile 25: 1.75941| Quartile 75: 75
# IQR: 0.7030050000000001
# Cut Off: 1.5
# Minimum: 0.2594099999999999
# Maximum: 3.962415
# Feature Outliers: 0
# outliers: []

# %%
hr.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
sns.swarmplot(hr['Health (Life Expectancy)'])
# Out:
# C:\Users\Laptop\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Health (Life Expectancy)'>

# %%
sns.histplot(hr['Health (Life Expectancy)'],kde=False)
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Count'>

# %%
sns.kdeplot(hr['Health (Life Expectancy)'],kernel='gau')
# Out:
# C:\Users\Laptop\anaconda3\lib\site-packages\seaborn\distributions.py:1666: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.kdeplot(hr['Health (Life Expectancy)'],kernel='cos')
# Out:
# C:\Users\Laptop\anaconda3\lib\site-packages\seaborn\distributions.py:1666: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.distplot(hr['Health (Life Expectancy)'],kde=True)
# Out:
# C:\Users\Laptop\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
box_plot_calculation(hr['Health (Life Expectancy)'])
# Out:
# Quartile 25: 0.439185| Quartile 75: 75
# IQR: 0.37182750000000003
# Cut Off: 1.5
# Minimum: -1.060815
# Maximum: 2.3110125
# Feature Outliers: 0
# outliers: []

# %%
sns.boxplot(hr['Health (Life Expectancy)'])
# Out:
# C:\Users\Laptop\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Health (Life Expectancy)'>

# %%
sns.distplot(hr['Trust (Government Corruption)'],kde=False)
# Out:
# C:\Users\Laptop\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Trust (Government Corruption)'>

# %%
sns.kdeplot(hr['Trust (Government Corruption)'],kernel='gau',bw='scott')
# Out:
# C:\Users\Laptop\anaconda3\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using scott for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\Laptop\anaconda3\lib\site-packages\seaborn\distributions.py:1666: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.kdeplot(hr['Trust (Government Corruption)'],kernel='gau',bw='silverman')
# Out:
# C:\Users\Laptop\anaconda3\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using silverman for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\Laptop\anaconda3\lib\site-packages\seaborn\distributions.py:1666: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.kdeplot(hr['Trust (Government Corruption)'],kernel='gau',bw=1)
# Out:
# C:\Users\Laptop\anaconda3\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\Laptop\anaconda3\lib\site-packages\seaborn\distributions.py:1666: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.kdeplot(hr['Trust (Government Corruption)'],kernel='gau',bw=0.001)
# Out:
# C:\Users\Laptop\anaconda3\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.001 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\Laptop\anaconda3\lib\site-packages\seaborn\distributions.py:1666: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(hr['Trust (Government Corruption)'],kde=True)
# Out:
# C:\Users\Laptop\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
box_plot_calculation(hr['Trust (Government Corruption)'])
# Out:
# Quartile 25: 0.061675| Quartile 75: 75
# IQR: 0.11857999999999999
# Cut Off: 1.5
# Minimum: -1.438325
# Maximum: 1.680255
# Feature Outliers: 0
# outliers: []

# %%
sns.boxplot(hr['Trust (Government Corruption)'])
# Out:
# C:\Users\Laptop\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Trust (Government Corruption)'>
