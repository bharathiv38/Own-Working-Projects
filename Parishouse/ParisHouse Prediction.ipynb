# %%
#lets load dependencies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#loading dataset to pandas dataframe
paris = pd.read_csv(r"C:\Users\User\Downloads\Parishouse\ParisHousingClass.csv")

# %%
#print first 5 rows of dataset
paris.head()
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0         75523              3        0        1      63      9373
# 1         80771             39        1        1      98     39381
# 2         55712             58        0        1      19     34457
# 3         32316             47        0        0       6     27939
# 4         70429             19        1        1      90     38045
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              3              8  2005           0                  1
# 1              8              6  2015           1                  0
# 2              6              8  2021           0                  0
# 3             10              4  2012           0                  1
# 4              3              7  1990           1                  0
#
#    basement  attic  garage  hasStorageRoom  hasGuestRoom      price category
# ...

# %%
paris.tail()
# Out:
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 9995          1726             89        0        1       5     73133
# 9996         44403             29        1        1      12     34606
# 9997         83841              3        0        0      69     80933
# 9998         59036             70        0        0      96     55856
# 9999          1440             84        0        0      49     18412
#
#       cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 9995              7              6  2009           0                  1
# 9996              9              4  1990           0                  1
# 9997             10             10  2005           1                  1
# 9998              1              3  2010           0                  1
# 9999              6             10  1994           1                  0
#
#       basement  attic  garage  hasStorageRoom  hasGuestRoom      price  \
# ...

# %%
#total rows and columns in dataset
paris.shape
# Out:
# (10000, 18)

# %%
#getting statistical information of data
paris.describe()
# Out:
#        squareMeters  numberOfRooms       hasYard       hasPool        floors  \
# count   10000.00000   10000.000000  10000.000000  10000.000000  10000.000000
# mean    49870.13120      50.358400      0.508700      0.496800     50.276300
# std     28774.37535      28.816696      0.499949      0.500015     28.889171
# min        89.00000       1.000000      0.000000      0.000000      1.000000
# 25%     25098.50000      25.000000      0.000000      0.000000     25.000000
# 50%     50105.50000      50.000000      1.000000      0.000000     50.000000
# 75%     74609.75000      75.000000      1.000000      1.000000     76.000000
# max     99999.00000     100.000000      1.000000      1.000000    100.000000
#
#            cityCode  cityPartRange  numPrevOwners         made    isNewBuilt  \
# count  10000.000000   10000.000000   10000.000000  10000.00000  10000.000000
# mean   50225.486100       5.510100       5.521700   2005.48850      0.499100
# ...

# %%
#gettin the dtypes in dataset
paris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   squareMeters       10000 non-null  int64
#  1   numberOfRooms      10000 non-null  int64
#  2   hasYard            10000 non-null  int64
#  3   hasPool            10000 non-null  int64
#  4   floors             10000 non-null  int64
#  5   cityCode           10000 non-null  int64
#  6   cityPartRange      10000 non-null  int64
#  7   numPrevOwners      10000 non-null  int64
#  8   made               10000 non-null  int64
#  9   isNewBuilt         10000 non-null  int64
#  10  hasStormProtector  10000 non-null  int64
#  11  basement           10000 non-null  int64
#  12  attic              10000 non-null  int64
#  13  garage             10000 non-null  int64
#  14  hasStorageRoom     10000 non-null  int64
#  15  hasGuestRoom       10000 non-null  int64
# ...

# %%
#finding the null values in dataset
paris.isnull().sum()
# Out:
# squareMeters         0
# numberOfRooms        0
# hasYard              0
# hasPool              0
# floors               0
# cityCode             0
# cityPartRange        0
# numPrevOwners        0
# made                 0
# isNewBuilt           0
# hasStormProtector    0
# basement             0
# attic                0
# garage               0
# hasStorageRoom       0
# hasGuestRoom         0
# price                0
# category             0
# dtype: int64

# %%
#lets find values in category
paris['category'].value_counts()
# Out:
# Basic     8735
# Luxury    1265
# Name: category, dtype: int64

# %% [markdown]
# # Data visualization

# %%
sns.set_theme()
sns.distplot(paris['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.lmplot(data=paris,x='squareMeters',y='price')

# %%
sns.distplot(paris['squareMeters'])
# Out:
# <AxesSubplot:xlabel='squareMeters', ylabel='Density'>

# %%
sns.distplot(np.log10(paris['squareMeters']))
# Out:
# <AxesSubplot:xlabel='squareMeters', ylabel='Density'>

# %%
sns.distplot(np.log10(paris['price']))
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
f=plt.figure(figsize=(14,6))
ax=f.add_subplot(121)
sns.violinplot(x='category',y='numberOfRooms',data=paris,palette='Wistia',ax=ax)
ax.set_title('Category Vs No of rooms')

ax=f.add_subplot(122)
sns.violinplot(x='category',y='hasGuestRoom',data=paris,palette='magma',ax=ax)
ax.set_title('Category Vs No of guest rooms')
# Out:
# Text(0.5, 1.0, 'Category Vs No of guest rooms')

# %%
f = plt.figure(figsize=(14,6))
ax=f.add_subplot(121)
sns.scatterplot(x='cityCode',y='price',data=paris,palette='magma',hue='isNewBuilt',ax=ax)
ax.set_title("CityCode Vs Price")

ax=f.add_subplot(122)
sns.scatterplot(x='cityPartRange',y='price',data=paris,palette='viridis',hue='made',ax=ax)
ax.set_title("City Range Vs Price")
# Out:
# Text(0.5, 1.0, 'City Range Vs Price')

# %%
plt.figure(figsize=(14,6))
sns.countplot(paris['made'])
# Out:
# <AxesSubplot:xlabel='made', ylabel='count'>

# %%
plt.figure(figsize=(14,6))
sns.barplot(x='category',y='price',hue='isNewBuilt',data=paris)
# Out:
# <AxesSubplot:xlabel='category', ylabel='price'>

# %%
plt.figure(figsize=(14,6))
sns.barplot(x='category',y='price',hue='made',data=paris)
# Out:
# <AxesSubplot:xlabel='category', ylabel='price'>

# %%
f = plt.figure(figsize=(14,6))
ax=f.add_subplot(121)
sns.scatterplot(x='category',y='basement',data=paris,palette='magma',hue='floors',ax=ax)
ax.set_title("category Vs yard")

ax=f.add_subplot(122)
sns.scatterplot(x='category',y='garage',data=paris,palette='viridis',hue='floors',ax=ax)
ax.set_title("category Vs pool")
# Out:
# Text(0.5, 1.0, 'category Vs pool')

# %%
corr = paris.corr(method= 'pearson')

# %%
plt.figure(figsize=(14,6))
sns.heatmap(corr,annot=True,cmap='Wistia',fmt=' .1f',cbar=True)
# Out:
# <AxesSubplot:>

# %%
paris['category'] = pd.factorize(paris['category'])[0]+1

# %%
X = paris.drop(columns='category',axis=1)
Y = paris['category']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=2)

# %% [markdown]
# # Scaling Technique

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler  = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train_std = scaler.transform(X_train)

X_test_std = scaler.transform(X_test)

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import precision_recall_curve, plot_precision_recall_curve, plot_roc_curve
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
error_rate =[]

for i in range(1,10):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train_std,Y_train)
    
    y_pred = knn.predict(X_test_std)
    
    test_error=1-accuracy_score(Y_test,y_pred)
    error_rate.append(test_error)

# %%
plt.figure(figsize=(8, 7))
plt.plot(range(1, 10), error_rate, label='Test Error')
plt.legend()
plt.ylabel('Error Rate')
plt.xlabel('K Value')
# Out:
# Text(0.5, 0, 'K Value')

# %%
knn_model = KNeighborsClassifier(n_neighbors=3)
knn_model.fit(X_train_std,Y_train)
y_pred  = knn_model.predict(X_test_std)
y_pred = pd.DataFrame(y_pred)
MSE = metrics.mean_squared_error(Y_test,y_pred)
RMSE = np.sqrt(MSE)
print(RMSE)
# Out:
# 0.08563488385776753

# %%
accuracy_score(Y_test,y_pred)
# Out:
# 0.9926666666666667

# %%
from sklearn.metrics import confusion_matrix, classification_report, plot_confusion_matrix
confusion_matrix(Y_test,y_pred)
# Out:
# array([[2638,    6],
#        [  16,  340]], dtype=int64)

# %%
plot_confusion_matrix(knn_model,X_test_std,Y_test)

# %%
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00      2644
#            2       0.98      0.96      0.97       356
#
#     accuracy                           0.99      3000
#    macro avg       0.99      0.98      0.98      3000
# weighted avg       0.99      0.99      0.99      3000
